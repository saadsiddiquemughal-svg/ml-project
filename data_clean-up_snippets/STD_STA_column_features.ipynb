# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
train_df = pd.read_csv('data/Train.csv')

# %%
train_df.dtypes
# Out:
# ID         object
# DATOP      object
# FLTID      object
# DEPSTN     object
# ARRSTN     object
# STD        object
# STA        object
# STATUS     object
# AC         object
# target    float64
# dtype: object

# %%
train_df.head()
# Out:
#            ID       DATOP     FLTID DEPSTN ARRSTN                  STD
# 0  train_id_0  2016-01-03  TU 0712     CMN    TUN  2016-01-03 10:30:00  \
# 1  train_id_1  2016-01-13  TU 0757     MXP    TUN  2016-01-13 15:05:00
# 2  train_id_2  2016-01-16  TU 0214     TUN    IST  2016-01-16 04:10:00
# 3  train_id_3  2016-01-17  TU 0480     DJE    NTE  2016-01-17 14:10:00
# 4  train_id_4  2016-01-17  TU 0338     TUN    ALG  2016-01-17 14:30:00
#
#                    STA STATUS         AC  target
# 0  2016-01-03 12.55.00    ATA  TU 32AIMN   260.0
# 1  2016-01-13 16.55.00    ATA  TU 31BIMO    20.0
# 2  2016-01-16 06.45.00    ATA  TU 32AIMN     0.0
# 3  2016-01-17 17.00.00    ATA  TU 736IOK     0.0
# 4  2016-01-17 15.50.00    ATA  TU 320IMU    22.0

# %%
def parse_datetime_columns(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    for col in ("STD", "STA"):
        df[col] = (
            df[col]
            .str.replace(".", ":", regex=False)
            .pipe(pd.to_datetime, errors="coerce")
        )
    return df

# %%
def add_flight_length_categories(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()

    duration_min = (df["STA"] - df["STD"]).dt.total_seconds() / 60

    df["flight_length_cat"] = pd.cut(
        duration_min,
        bins=[0, 90, 240, float("inf")],
        labels=["short", "medium", "long"],
        include_lowest=True
    ).astype("string")

    return df

# %%
def add_flight_duration_bins(
    df: pd.DataFrame,
    bin_size: int = 60
) -> pd.DataFrame:
    
    df = df.copy()

    # Handle overnight flights: if STA < STD, add 1 day to STA
    sta_adjusted = df["STA"].where(
        df["STA"] >= df["STD"],
        df["STA"] + pd.Timedelta(days=1)
    )

    duration_min = (sta_adjusted - df["STD"]).dt.total_seconds() / 60


    # Build duration bins
    start = (duration_min // bin_size) * bin_size
    end = start + bin_size - 1

    df["flight_duration_bin"] = (
        start.astype(int).astype(str)
        + "-"
        + end.astype(int).astype(str)
    )

    return df

# %%
def add_time_of_day_categories(df: pd.DataFrame) -> pd.DataFrame:
    """
    Adds time-of-day categories based on scheduled departure time (STD).

    Categories:
    night      : 00–05
    morning    : 06–11
    midday     : 12–14
    afternoon  : 15–18
    evening    : 19–23
    """
    df = df.copy()

    hour = df["STD"].dt.hour

    df["time_of_day_cat"] = pd.cut(
        hour,
        bins=[-1, 5, 11, 14, 18, 23],
        labels=["night", "morning", "midday", "afternoon", "evening"]
    ).astype("string")

    return df

# %%
train_fe = (
    train_df.pipe(parse_datetime_columns)
            .pipe(add_flight_length_categories)
            .pipe(add_flight_duration_bins, bin_size=60)
            .pipe(add_time_of_day_categories)
)
    
train_fe.head(25)
# Out:
#              ID       DATOP     FLTID DEPSTN ARRSTN                 STD
# 0    train_id_0  2016-01-03  TU 0712     CMN    TUN 2016-01-03 10:30:00  \
# 1    train_id_1  2016-01-13  TU 0757     MXP    TUN 2016-01-13 15:05:00
# 2    train_id_2  2016-01-16  TU 0214     TUN    IST 2016-01-16 04:10:00
# 3    train_id_3  2016-01-17  TU 0480     DJE    NTE 2016-01-17 14:10:00
# 4    train_id_4  2016-01-17  TU 0338     TUN    ALG 2016-01-17 14:30:00
# 5    train_id_5  2016-01-17  TU 0283     TLS    TUN 2016-01-17 16:20:00
# 6    train_id_6  2016-01-18  TU 0514     TUN    BCN 2016-01-18 07:15:00
# 7    train_id_7  2016-01-18  TU 0716     TUN    ORY 2016-01-18 07:35:00
# 8    train_id_8  2016-01-18  TU 0752     TUN    FCO 2016-01-18 07:40:00
# 9    train_id_9  2016-01-18  TU 0996     TUN    NCE 2016-01-18 07:45:00
# 10  train_id_10  2016-01-18  TU 0930     TUN    MRS 2016-01-18 07:55:00
# 11  train_id_11  2016-01-20  TU 0724     TUN    ORY 2016-01-20 18:30:00
# 12  train_id_12  2016-01-20  TU 0913     TUN    MED 2016-01-20 19:40:00
# 13  train_id_13  2016-01-21  TU 0217     IST    TUN 2016-01-21 20:10:00
# 14  train_id_14  2016-01-22  TU 0744     TUN    FRA 2016-01-22 07:05:00
# 15  train_id_15  2016-01-22  TU 0706     CMN    TUN 2016-01-22 17:45:00
# 16  train_id_16  2016-01-22  TU 0723     ORY    TUN 2016-01-22 18:30:00
# 17  train_id_17  2016-01-23  TU 0726     MIR    BRU 2016-01-23 05:30:00
# 18  train_id_18  2016-01-22  TU 0913     TUN    MED 2016-01-22 19:40:00
# 19  train_id_19  2016-01-23  TU 9038     TUN    DJE 2016-01-23 08:50:00
# 20  train_id_20  2016-01-23  TU 0717     ORY    TUN 2016-01-23 10:55:00
# 21  train_id_21  2016-01-24  TU 0430     DJE    LYS 2016-01-24 14:05:00
# 22  train_id_22  2016-01-27  TU 0789     BRU    TUN 2016-01-27 11:35:00
# 23  train_id_23  2016-02-01  TU 0913     TUN    MED 2016-02-01 19:40:00
# 24  train_id_24  2016-02-02  TU 0711     TUN    CMN 2016-02-02 06:55:00
#
#                    STA STATUS         AC  target flight_length_cat
# 0  2016-01-03 12:55:00    ATA  TU 32AIMN   260.0            medium  \
# 1  2016-01-13 16:55:00    ATA  TU 31BIMO    20.0            medium
# 2  2016-01-16 06:45:00    ATA  TU 32AIMN     0.0            medium
# 3  2016-01-17 17:00:00    ATA  TU 736IOK     0.0            medium
# 4  2016-01-17 15:50:00    ATA  TU 320IMU    22.0             short
# 5  2016-01-17 18:15:00    ATA  TU 736IOP    53.0            medium
# 6  2016-01-18 09:00:00    ATA  TU 32AIMH    10.0            medium
# 7  2016-01-18 09:55:00    ATA  TU 32AIMI    15.0            medium
# 8  2016-01-18 09:00:00    ATA  TU 32AIMC    16.0             short
# 9  2016-01-18 09:15:00    ATA  TU 31AIMK    21.0             short
# 10 2016-01-18 09:30:00    ATA  TU 32AIMF    12.0            medium
# 11 2016-01-20 20:50:00    ATA  TU 32AIMP    18.0            medium
# 12 2016-01-21 00:00:00    ATA  TU 320IMR     0.0              long
# 13 2016-01-21 23:00:00    ATA  TU 320IMU     0.0            medium
# 14 2016-01-22 09:40:00    ATA  TU 736IOP    18.0            medium
# 15 2016-01-22 20:10:00    ATA  TU 320IMR     0.0            medium
# 16 2016-01-22 21:00:00    ATA  TU 332IFN    37.0            medium
# 17 2016-01-23 08:15:00    ATA  TU 31AIMJ   149.0            medium
# 18 2016-01-23 00:00:00    ATA  TU 320IMT    30.0              long
# 19 2016-01-23 09:45:00    ATA  TU 736IOL    19.0             short
# 20 2016-01-23 13:20:00    ATA  TU 32AIMI    27.0            medium
# 21 2016-01-24 16:25:00    ATA  TU 31AIMJ     0.0            medium
# 22 2016-01-27 14:15:00    ATA  TU 32AIMF    31.0            medium
# 23 2016-02-02 00:00:00    ATA  TU 320IMT    10.0              long
# 24 2016-02-02 09:40:00    ATA  TU 320IMU    24.0            medium
#
#    flight_duration_bin time_of_day_cat
# 0              120-179         morning
# 1               60-119       afternoon
# 2              120-179           night
# 3              120-179          midday
# 4               60-119          midday
# 5               60-119       afternoon
# 6               60-119         morning
# 7              120-179         morning
# 8               60-119         morning
# 9               60-119         morning
# 10              60-119         morning
# 11             120-179       afternoon
# 12             240-299         evening
# 13             120-179         evening
# 14             120-179         morning
# 15             120-179       afternoon
# 16             120-179       afternoon
# 17             120-179           night
# 18             240-299         evening
# 19                0-59         morning
# 20             120-179         morning
# 21             120-179          midday
# 22             120-179         morning
# 23             240-299         evening
# 24             120-179         morning

# %%
train_fe['flight_duration_bin'].max()
# Out:
# '9720-9779'

# %%
train_fe['flight_length_cat'].value_counts()
# Out:
# flight_length_cat
# medium    75153
# short     23905
# long       8775
# Name: count, dtype: Int64

# %%
train_fe.loc[train_fe['DEPSTN'] == train_fe['ARRSTN'], 'target']
# Out:
# 298        35.0
# 418         3.0
# 461        17.0
# 1107       10.0
# 1294      135.0
#           ...
# 107821      0.0
# 107825      0.0
# 107827      0.0
# 107828      0.0
# 107830      0.0
# Name: target, Length: 5523, dtype: float64

# %%
train_fe.groupby('STATUS')['target'].mean() 
train_fe['STATUS'].value_counts()
# Out:
# STATUS
# ATA    93679
# SCH    13242
# DEP      467
# RTR      294
# DEL      151
# Name: count, dtype: int64
