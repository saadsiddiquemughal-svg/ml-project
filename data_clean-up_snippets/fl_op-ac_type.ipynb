# %%
import numpy as np
import pandas as pd

# %%
#test = pd.read_csv('../data/test.csv')
train = pd.read_csv('../Train_modified.csv')
#sample = pd.read_csv('../data/SampleSubmission.csv')

# %%
train['fl_op'] = train['FLTID'].str[:3]

condition = [
    (train["fl_op"] == 'TU '),
    (train["fl_op"] == 'UG '),
    (train["fl_op"] == 'WKL'),
    (train["fl_op"] != 'TU ')
]

choices = [1, 2, 3, 4]

train["fl_op"] = np.select(condition, choices, default=np.nan)
train.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'ID', 'DATOP', 'FLTID', 'DEPSTN',
#        'ARRSTN', 'STD', 'STA', 'AC', 'target', 'ATA', 'SCH', 'month_DATOP',
#        'year_DATOP', 'weekdays_DATOP', 'flight_duration_hrs',
#        'flight_duration_category', 'fl_op'],
#       dtype='object')

# %%
train['ac_type'] = train['AC'].str[3:5]

condition = [
    (train["ac_type"] == '32'), #A320
    (train["ac_type"] == '31'), #A310
    (train["ac_type"] == '73'), #B737
    (train["ac_type"] == '33'), #A330
    (train["ac_type"] == 'CR'), #CR
    (train["ac_type"] == '34'), #A340
    (train["ac_type"] == 'AT'), #AT
    (train["ac_type"] == 'M8'), #M8
]

choices = [1, 2, 3, 4, 5, 6, 7, 8]

train["ac_type"] = np.select(condition, choices, default=np.nan)
train.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'ID', 'DATOP', 'FLTID', 'DEPSTN',
#        'ARRSTN', 'STD', 'STA', 'AC', 'target', 'ATA', 'SCH', 'month_DATOP',
#        'year_DATOP', 'weekdays_DATOP', 'flight_duration_hrs',
#        'flight_duration_category', 'fl_op', 'ac_type'],
#       dtype='object')

# %%
train.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0          ID       DATOP     FLTID DEPSTN ARRSTN
# 0             0           0  train_id_0  2016-01-03  TU 0712     CMN    TUN  \
# 1             1           1  train_id_1  2016-01-13  TU 0757     MXP    TUN
# 2             2           2  train_id_2  2016-01-16  TU 0214     TUN    IST
# 3             3           3  train_id_3  2016-01-17  TU 0480     DJE    NTE
# 4             4           4  train_id_4  2016-01-17  TU 0338     TUN    ALG
#
#                    STD                  STA         AC  target   ATA    SCH
# 0  2016-01-03 10:30:00  2016-01-03 12:55:00  TU 32AIMN   260.0  True  False  \
# 1  2016-01-13 15:05:00  2016-01-13 16:55:00  TU 31BIMO    20.0  True  False
# 2  2016-01-16 04:10:00  2016-01-16 06:45:00  TU 32AIMN     0.0  True  False
# 3  2016-01-17 14:10:00  2016-01-17 17:00:00  TU 736IOK     0.0  True  False
# 4  2016-01-17 14:30:00  2016-01-17 15:50:00  TU 320IMU    22.0  True  False
#
#    month_DATOP  year_DATOP  weekdays_DATOP  flight_duration_hrs
# 0            1        2016               6             2.416667  \
# 1            1        2016               2             1.833333
# 2            1        2016               5             2.583333
# 3            1        2016               6             2.833333
# 4            1        2016               6             1.333333
#
#   flight_duration_category  fl_op  ac_type
# 0                     long    1.0      1.0
# 1                   medium    1.0      2.0
# 2                     long    1.0      1.0
# 3                     long    1.0      3.0
# 4                   medium    1.0      1.0

# %%
train.to_csv('../Train_modified.csv')
